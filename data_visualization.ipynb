# %% [markdown]
# <a href="https://colab.research.google.com/github/Shriya33/Data-Science-Internship-Basics/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate random data
x = np.linspace(0, 10, 100)
y = np.sin(x) + np.random.normal(0, 0.1, 100)
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Random Data', color='blue', linewidth=2)
plt.title('Random Data Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.savefig('plot.png')
plt.show()
